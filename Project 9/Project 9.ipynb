# %% [markdown]
# # INTRODUCCIÓN

# %% [markdown]
# Se ha decidido abrir un café regentado por robots en Los Ángeles y se debe atraer a inversionistas. Con datos procedentes de fuentes abiertas sobre restaurantes en Los Ángeles hay que decidir si el café seguirá teniendo éxito cuando la novedad de los camareros robot desaparezca.
#
# Para esto se van a preparar los datos para luego realizar un análisis. Luego se preparara una presentación con el debido formato y las conclusiones.

# %% [markdown]
# # TABLA DE CONTENIDO

# %% [markdown]
# # 1. Preparación de datos
# # 2. Análisis de datos
# # 3. Presentación
# # 4. Conclusión y recomendaciones

# %%
#importando los paquetes
import pandas as pd
from plotly import graph_objects as go
import plotly.express as px
import seaborn as sns


#import datetime as dt
#import numpy as np
import matplotlib.pyplot as plt
#import scipy.stats as stats

# %% [markdown]
# ## PREPARACIÓN DE DATOS

# %%
#guardando y mostrando el dataset
try:
    rest_data = pd.read_csv("/datasets/rest_data_us.csv")
except:
    rest_data = pd.read_csv("rest_data_us.csv")
    
rest_data.head()
# Out:
#       id          object_name                    address  chain object_type  \
# 0  11786  HABITAT COFFEE SHOP     3708 N EAGLE ROCK BLVD  False        Cafe
# 1  11787             REILLY'S        100 WORLD WAY # 120  False  Restaurant
# 2  11788       STREET CHURROS  6801 HOLLYWOOD BLVD # 253  False   Fast Food
# 3  11789    TRINITI ECHO PARK         1814 W SUNSET BLVD  False  Restaurant
# 4  11790               POLLEN         2100 ECHO PARK AVE  False  Restaurant
#
#    number
# 0      26
# 1       9
# 2      20
# 3      22
# 4      20

# %%
#observando el tipo de datos
rest_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9651 entries, 0 to 9650
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           9651 non-null   int64
#  1   object_name  9651 non-null   object
#  2   address      9651 non-null   object
#  3   chain        9648 non-null   object
#  4   object_type  9651 non-null   object
#  5   number       9651 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 452.5+ KB

# %% [markdown]
# Valores ausentes: Existen 3 valores ausentes en la columna "chain" que se deben trabajar.
#
# Tipo de dato: La columna "chain" debe ser tipo bool.

# %% [markdown]
# ### Verificando valores duplicados

# %%
#verificando si hay valores duplicados
rest_data[["object_name","address"]].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Verificando y rellenando valores ausentes

# %%
#contando los valores en "chain"
rest_data["chain"].value_counts()
# Out:
# False    5972
# True     3676
# Name: chain, dtype: int64

# %%
#verificando los valores ausentes en "chain"
rest_data[rest_data["chain"].isna()]
# Out:
#          id              object_name               address chain object_type  \
# 7408  19194  TAQUERIA LOS 3 CARNALES  5000 E WHITTIER BLVD   NaN  Restaurant
# 7523  19309     JAMMIN JIMMY'S PIZZA   1641 FIRESTONE BLVD   NaN       Pizza
# 8648  20434    THE LEXINGTON THEATER          129 E 3RD ST   NaN  Restaurant
#
#       number
# 7408      14
# 7523       1
# 8648      35

# %%
#creando un dataset con la cantidad de locales de cada restaurante
rest_quantity = rest_data.groupby("object_name").agg({"id":"count"}).sort_values(by="id", ascending=False).reset_index()
rest_quantity.columns = ["name", "count"]
rest_quantity.head()
# Out:
#                          name  count
# 0  THE COFFEE BEAN & TEA LEAF     47
# 1                      SUBWAY     31
# 2              DOMINO'S PIZZA     15
# 3      KENTUCKY FRIED CHICKEN     14
# 4                  WABA GRILL     14

# %%
#calculando la cantidad de restaurantes que tienen más de un local en el dataset
chain_list = rest_quantity[rest_quantity["count"] > 1]["name"]
chain_list.count()
# Out:
# 524

# %%
#calculando la cantidad de restaurantes que solo tienen un local en el dataset
no_chain_list = rest_quantity[rest_quantity["count"] == 1]["name"]
no_chain_list = list(no_chain_list)
len(no_chain_list)
# Out:
# 8148

# %% [markdown]
# No hay forma de determinar a través de los datos si los datos faltantes en "chain" son False o no. Hay algunos restaurantes que si pertenecen a una cadena pero que solo hay un restaurant en la base de datos, por lo que no se puede decir que si solo hay uno en el dataset, significa que no pertenece a una cadena. Esto significa que es mejor eliminar los datos faltantes para que no interfieran en las conclusiones. La eliminación de estos datos no afectará tanto ya que solo son 3 datos, es decir el 0.03% de los datos.

# %%
#obteniendo la información del dataset
rest_data = rest_data.dropna()
rest_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9648 entries, 0 to 9650
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           9648 non-null   int64
#  1   object_name  9648 non-null   object
#  2   address      9648 non-null   object
#  3   chain        9648 non-null   object
#  4   object_type  9648 non-null   object
#  5   number       9648 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 527.6+ KB

# %%
#verificando los valores ausentes en "chain"
rest_data[rest_data["chain"].isna()]
# Out:
# Empty DataFrame
# Columns: [id, object_name, address, chain, object_type, number]
# Index: []

# %% [markdown]
# ### Cambiando los tipos de datos

# %%
rest_data["chain"] = rest_data["chain"].astype("bool")
rest_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9648 entries, 0 to 9650
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           9648 non-null   int64
#  1   object_name  9648 non-null   object
#  2   address      9648 non-null   object
#  3   chain        9648 non-null   bool
#  4   object_type  9648 non-null   object
#  5   number       9648 non-null   int64
# dtypes: bool(1), int64(2), object(3)
# memory usage: 461.7+ KB

# %% [markdown]
# ## ANÁLISIS DE DATOS

# %% [markdown]
# ### Proporciones de tipos de establecimientos

# %%
#agrupando los datos para graficar
type_list = rest_data.groupby("object_type").agg({"id":"count"}).sort_values(by="id", ascending=False).reset_index()
type_list.columns = ["type", "count"]
type_list
# Out:
#          type  count
# 0  Restaurant   7253
# 1   Fast Food   1066
# 2        Cafe    435
# 3       Pizza    319
# 4         Bar    292
# 5      Bakery    283

# %%
#graficando la proporción de los tipos de establecimientos
type_rest = list(type_list["type"])
count_rest = list(type_list["count"])
fig = go.Figure(data = [go.Pie(labels = type_rest, values = count_rest, title="Tipos de establecimientos")])
fig.show()
# Out:
# <div>                            <div id="68c275aa-af37-4fd8-9b71-230a259b1c2c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("68c275aa-af37-4fd8-9b71-230a259b1c2c")) {                    Plotly.newPlot(                        "68c275aa-af37-4fd8-9b71-230a259b1c2c",                        [{"labels":["Restaurant","Fast Food","Cafe","Pizza","Bar","Bakery"],"title":{"text":"Tipos de establecimientos"},"values":[7253,1066,435,319,292,283],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker ...
#
# var gd = document.getElementById('68c275aa-af37-4fd8-9b71-230a259b1c2c');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{

# %% [markdown]
# ### Proporciones de tipos de establecimientos que pertenecen o no a una cadena

# %%
#contando los valores en "chain"
chain_ratio = rest_data.groupby("chain").agg({"id":"count"}).reset_index()
chain_ratio.columns = ["is_chain", "quantity"]
chain_ratio
# Out:
#    is_chain  quantity
# 0     False      5972
# 1      True      3676

# %%
#graficando la proporción de establecimientos en cadena e independientes
is_chain = list(chain_ratio["is_chain"])
quantity = list(chain_ratio["quantity"])
fig = go.Figure(data = [go.Pie(labels = is_chain, values = quantity, title="Proporción de establecimientos en cadena")])
fig.show()
# Out:
# <div>                            <div id="b794a376-7da3-42b0-a132-f9b998974a49" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b794a376-7da3-42b0-a132-f9b998974a49")) {                    Plotly.newPlot(                        "b794a376-7da3-42b0-a132-f9b998974a49",                        [{"labels":[false,true],"title":{"text":"Proporci\u00f3n de establecimientos en cadena"},"values":[5972,3676],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks": ...
#
# var gd = document.getElementById('b794a376-7da3-42b0-a132-f9b998974a49');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);

# %%
#agrupando para graficar
type_list = rest_data.groupby(["chain", "object_type"]).agg({"id":"count"}).sort_values(by="id", ascending=False).reset_index()
type_list.columns = ["chain", "type", "count"]
type_list
# Out:
#     chain        type  count
# 0   False  Restaurant   4961
# 1    True  Restaurant   2292
# 2    True   Fast Food    605
# 3   False   Fast Food    461
# 4    True      Bakery    283
# 5    True        Cafe    266
# 6   False         Bar    215
# 7   False        Cafe    169
# 8   False       Pizza    166
# 9    True       Pizza    153
# 10   True         Bar     77

# %%
#graficando la proporción de los tipos de establecimientos por grupo (si son cadena o no)
fig = px.bar(type_list, x="type", y="count", color="chain", title="Cantidad de establecimientos diferenciado por grupo (cadena o no cadena)")
fig.show()
# Out:
# <div>                            <div id="9deec1a1-cf1e-4aa2-86ec-4ea99225972d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9deec1a1-cf1e-4aa2-86ec-4ea99225972d")) {                    Plotly.newPlot(                        "9deec1a1-cf1e-4aa2-86ec-4ea99225972d",                        [{"alignmentgroup":"True","hovertemplate":"chain=False<br>type=%{x}<br>count=%{y}<extra></extra>","legendgroup":"False","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"False","offsetgroup":"False","orientation":"v","showlegend":true,"textposition":"auto","x":["Restaurant","Fast Food","Bar","Cafe","Pizza"],"xaxis":"x","y":[4961,461,215,169,166],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"chain=True<br>type=%{x}<br>count=%{y}<extra></extra>","legendgroup":"True","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"True","offsetgroup":"True","orientation":"v","showlegend":true,"textposition":"auto","x":["Restaurant","Fast Food","Bakery","Cafe","Pizza","Bar"],"xaxis":"x","y":[2292,605,283,266,153,77],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"sc ...

# %% [markdown]
# ### ¿Qué tipo de establecimiento es habitualmente una cadena?

# %% [markdown]
# Como se ve en el gráfico anterior, los establecimientos que son bakery habitualmente son cadena, de hecho no hay información sobre bakerys que no pertenezcan a una cadena.
#
# Además, los establecimientos de fast food y de café tambien en su mayoría son parte de una cadena, aunque en menor proporción que bakery.

# %% [markdown]
# ### ¿Qué caracteriza a las cadenas?

# %%
#creando un dataset solo con los datos pertenecientes a las cadenas
chain_list = rest_data.query('chain == True')
chain_list.columns = ["id", "object_name", "address", "chain", "object_type", "seats"]
chain_list.head()
# Out:
#        id               object_name                          address  chain  \
# 8   11794                ABC DONUTS  3027 N SAN FERNANDO RD UNIT 103   True
# 10  11796             EL POLLO LOCO               5319 W SUNSET BLVD   True
# 11  11797         POONG NYUN BAKERY        928 S WESTERN AVE STE 109   True
# 12  11798  EMC RESTAURANT GROUP LLC            3500 W 6TH ST STE 101   True
# 14  11800         CUSCATLECA BAKERY            2501 W SUNSET BLVD #A   True
#
#    object_type  seats
# 8    Fast Food      1
# 10  Restaurant     38
# 11      Bakery     17
# 12  Restaurant    133
# 14      Bakery     26

# %%
#graficando un histograma
fig = px.histogram(chain_list, x="seats", nbins = 20, title="Distribución del número de asientos en establecimientos en cadena")
fig.show()
# Out:
# <div>                            <div id="d0bf18e0-ff89-4657-8630-18eef52bf4e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0bf18e0-ff89-4657-8630-18eef52bf4e2")) {                    Plotly.newPlot(                        "d0bf18e0-ff89-4657-8630-18eef52bf4e2",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"seats=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":20,"offsetgroup":"","orientation":"v","showlegend":false,"x":[1,38,17,133,26,21,43,80,15,118,35,15,1,19,49,37,158,22,35,20,28,27,2,21,24,16,24,66,112,21,27,3,45,63,121,20,15,16,6,4,3,40,88,40,42,19,5,9,4,128,224,36,6,11,23,107,134,25,37,1,16,20,21,45,40,20,4,26,17,24,21,35,5,2,21,17,133,44,7,23,23,3,43,15,15,34,123,10,27,44,27,46,77,6,21,15,19,14,45,14,49,11,18,18,79,22,37,12,109,13,182,44,18,10,23,24,81,69,39,25,12,5,117,13,48,15,41,167,31,16,44,29,5,27,35,19,9,46,111,28,11,43,164,35,11,19,129,1,27,85,29,33,5,196,1,46,84,91,21,25,9,47,88,12,23,3,5,11,41,20,20,20,33,139,25,29,28,7,98,227,158,43,12,43,229,39,8,43,28,37,34,24,16,12,49,13,11,38,13,13,112,10,9,3,155,25,49,6,2,32,11,13,40,7,11,33,9,5,102,44,10,14,2,15,229,47,33,65,20,41,24,9,42,6,34,12,74,32,49,39,26,46,40,138,25,26,22,31,4,109,24,7,13,119,71,40,21,21,118,6,11,9,10,14,19,17,69,104,12,9,28,62,90,11,20,2,15,12,29,20,23,45,84,12,36,151,186,6,17,12,44,48,23,13,43,5,16,23,4,136,119,106,40,26,14,16,12,11,7,29,41,45,22,22,7,17,90,21,1,43,107,36,10,110,10,45,86,37,24,38,11,44,17,67,20,194,29,29,25,16,28,13,7,9,29,1,8,45,6,19,3,13,16,37,3,18,20,2,25,126,6,3,127,3,91,32,29,15,43,42,3,47,91,12,23,21,9,6,47,14,1,7,19,81,104,4,6,26,16,37,25,17,7,20,43,142,10,20,47,5,12,103,22,69,212,161,22,13,38,226,27,42,82,28,41,19,5,13,15,1,140,18,13,42,26,18,14,11,92,17,7,3,83,19,118,24,110,19,19,18,27,124,19,22,43,10,42,84,12,74,8,33,22,80,12,83,19,19,8,13,115,25,7,86,181,32,24,10,26,42,111,108,5,15,64,9,131,36,26,39,12,25,49,15,159,4,13,41,42,107,74,64,32,20,36,182,2,29,20,185,2,65,32,45,29,23,66,175,11,18,172,45,9,84,2,116,28,113,38,10,142,141,45,11,37,29,32,40,80,19,6,5,20,24,17,14,110,189,178,37,180,10,9,123,48,29,45,1,75,21,112,131,40,26,107,195,216,21,7,44,37,3,1,220,88,35,32,21,6,3,7,107,11,63,6,12,20,85,21,69,13,63,2,25,19,47,1,77,44,3,107,102,41,83,181,93,21,11,119,25,31,8,26,28,20,225,10,21,41,114,21,49,3,137,9,66,74,41,18,18,19,44,38,49,48,47,44,41,43,49,1,45,68,7,13,6,43,48,17,63,44,48,37,160,37,17,194,1,13,22,101,12,17,18,46,20,25,23,138,28,107,42,117,23,1,4,35,41,35,43,15,19,221,210,139,35,19,45,48,45,49,31,45,41,1,104,47,29,24,85,27,18,39,24,120,20,103,77,1,145,23,28,227,148,13,115,21,6,17,4,12,225,17,43,194,28,22,1,28,33,1,14,109,13,23,8,13,6,26,16,1,41,178,11,83,137,5,17,40,4,25,31,175,3,37,22,23,31,31,27,24,218,44,49,5,13,6,39,158,10,15,18,44,2,35,114,13,33,102,36,136,24,28,11,128,23,27,23,211,8,85,38,69,20,48,127,13,125,15,102,75,126,11,23,12,47,4,10,36,127,164,16,3,10,48,20,33,37,177,39,13,8,4,31,35,20,48,3,181,28,24,24,6,24,16,9,110,74,66,27,21,5,29,4,42,36,1,28,23,12,25,32,87,15,41,29,140,28,5,33,21,3,16,16,119,1,102,216,43,45,36,29,20,47,48,49,143,14,29,148,7,27,35,5,5,32,10,42,9,42,18,22,44,6,31,27,2,3,12,28,91,67,66,161,34,117,27,36,43,40,25,129,9,2,39,21,80,65,69,161,22,213,144,7,13,35,20,1,3,28,10,67,190,24,115,10,21,112,2,68,6,13,109,159,203,107,41,49,39,198,38,37,12,11,74,47,45,33,48,170,11,28,7,4,34,6,40,175,42,9,45,32,144,14,16,43,11,38,46,17,5,142,192,23,25,14,18,2,19,25,49,96,38,32,25,38,46,25,116,8,31,23,4,18,20,44,18,46,47,8,46,7,12,41,26,62,47,63,24,105,25,39,9,39,33,18,8,28,38,33,219,37,33,32,2,27,9,4,15,31,34,26,7,28,69,38,41,39,3,12,26,22,33,137,32,217,22,12,10,10,2,2,43,2,145,20,122,45,118,36,47,7,15,15,4,24,19,16,21,8,49,5,24,7,27,2,38,49,47,32,3 ...

# %% [markdown]
# Se observa en el histograma que en general los establecimientos de cadena tienen pocos asientos, el mayor tramo está entre 0 y 19 asientos, esto se puede deber a que las cadenas priorizan la rotación rápida de los clientes.

# %%
#obteniendo información sobre la cantidad de establecimientos
chain_list["seats"].describe()
# Out:
# count    3676.000000
# mean       39.694233
# std        43.437212
# min         1.000000
# 25%        13.000000
# 50%        25.000000
# 75%        44.000000
# max       229.000000
# Name: seats, dtype: float64

# %% [markdown]
# Solo el 25% de los establecimientos tienen más de 44 asientos.

# %%
#graficando un histograma
fig = px.histogram(chain_list, x="object_name", nbins = 50, title="Distribución del número de locales por cadena")
fig.show()
# Out:
# <div>                            <div id="2c15bd7e-52e1-4369-81f2-eb288b203691" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c15bd7e-52e1-4369-81f2-eb288b203691")) {                    Plotly.newPlot(                        "2c15bd7e-52e1-4369-81f2-eb288b203691",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"object_name=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":50,"offsetgroup":"","orientation":"v","showlegend":false,"x":["ABC DONUTS","EL POLLO LOCO","POONG NYUN BAKERY","EMC RESTAURANT GROUP LLC","CUSCATLECA BAKERY","FOOD COURT TRAY WASHING AREA","M CAFE DE CHAYA","NORM'S RESTAURANT","KRISPY KRUNCHY CHICKEN - ALVARADO","DUNES RESTAURANT","ONO HAWAIIAN BBQ","MUSH BAKERY","REGGIE'S DELI & CAFE","HOT THAI RESTAURANT","WABA GRILL","SUBWAY -52105","IHOP","PANDA EXPRESS #2596","LA MONARCA BAKERY","THE COUNTER SPACE 7C","TOGO'S","JACKY'S RESTAURANT","BASE COAT -JUICE BAR","KIKKA @ ARCO PLAZA","JOHNNIE'S NEW YORK PIZZA","EAGLE ROCK BREWERY","DONUT STAR","ROSE GARDEN CAFE","MCDONALD'S #2084","BLD","LOCALI","SUBWAY #39685","LEMONADE RESTAURANT","LA SIRENA RESTAURANT","JACK IN THE BOX # 335","FOOD PICNIC DAY","JIN RESTAURANT","CELAYA BAKERY","K-BAKERY","LOS PINITOS NUEVOS BAKERY","SHAKE SHACK","JOHNNY ROCKETS","MCDONALD'S # 10129","ZANKOU CHICKEN","JIM'S BURGERS","DER WIENERSCHNITZEL #20","DELICIAS BAKERY AND SOME","TUTTI FRUTTI","SUBWAY #14183","JACK IN THE BOX # 3348","TRASTEVERE RESTAURANT","MARIE'S COFFEE AND DELI","KABAN PERSIAN RESTAURANT","ANGELINI ALIMENTARI","YANUSA SUSHI RESTAURANT","MALIBU FISH GRILL","THE VEGGIE GRILL","ASHLAND BAR EARTH BAR / PANDA EXPRESS ASHLAND HILL","CARL'S JR","KIKKA SUSHI","PIZZA HUT #26158","WH POKE BAR INC.","JAMBA JUICE #527","PANDA EXPRESS #1212","MARISCOS EL CAMARON PELADO RESTAURANT","INK SACK","ANDANTE COFFEE ROASTERS","LA AZTECA TORTILLERIA & RESTAURANT","RESTAURANTE EL QUETZALITO","SUBWAY #12484","COGNOSCENTI COFFEE","YOSHINOYA #1147","TACO BELL #3141","LE BALCON BAKERY","FOOD 4 LESS #362","SUBWAY #1763","IHOP #782","HONG KONG RESTAURANT","PIZZA HUT #26178","OPERA HOUSE BAKERY","COCO FRESH TEA AND JUICE","ALVAREZ BAKERY","CEMITAS POBLANAS MI MAGDALENA RESTAURANT #2","SUPER A FOODS","FOOD 4 LESS #777","OCHA RESTAURANT","POLLO CAMPERO","VAN BAKERY","GOURMENT LA BAKERY","CURRY HOUSE COCOICHIBANYA","LOUISIANA FRIED CHICKEN #4050","SHERATON HOTEL","TEUM RESTAURANT, INC.","DONA INEZ RESTAURANTE TU COCINA MEXICANA","MOMOTA RAMEN HOUSE","DOWNTOWN FATBURGER","DELI IN","DELICIOUS PIZZA SUNSET BLVD.","JACK IN THE BOX #3393","SUBWAY","ARADO JAPANESE RESTAURANT","THE HEIGHTS DELI AND BOTTLE SHOP","LE CAFE BONJOUR","CAMPOS TACOS","STAR KARAOKE","VANESSA'S BAKERY","THE OINKSTER","PIZZA STUDIO","OB BEAR RESTAURANT","CAFE DELI E PARK CENTRAL BLD","ROCK N FISH","SIMPLY SALAD","IL BAMBINO RESTAURANT","CAPTAIN LEE'S SEAFOOD","DR .SEBI'S  CELLFOOD","SUBWAY #23131","TREJO'S TACOS","THE VEGGIE GRILL","SALATA ON FLOWER","KENTUCKY FRIED CHICKEN","BARISTA SOCIETY","PAYLESS FOODS MKT","CORAL REEF RESTAURANT","DELICIOUS TOGETHER","EL POLLO LOCO #5322","PIZZA HUT #25408","BURGER KING # 1417","HOOTERS RESTAURANTS","SAFFRON","NENA RESTAURANT","VILLANUEVA RESTAURANT & BAR","SUBWAY SANDWICHES","MR BOBA","MEATLAND BAKERY","THE ORIGINAL RINALDI'S DELI AND CAFE","J AND P DELI","FOOD 4 LESS #399","LAS CHAMPAS RESTAURANT #12","WABA GRILL","SEEMA'S BURGERIM","BELWOOD BAKERY","BOMBAY GRILL INDIAN FOOD","HARD ROCK CAFE HOLLYWOOD","MCDONALD'S # 18368","WHICH WICH #403","TRIMANA","BAJA FRESH","JAMBA JUICE #1546","DONUT STAR","ROCK N ROLL SUSHI","MR. HOLMES BAKEHOUSE","TRIMANA","JENI'S SPLENDID ICE CREAM","MCDONALD'S #6688","POKE BAR","SANSAI JAPANESE GRILL","CLEO","LOS ANGELES TENNIS ...

# %% [markdown]
# Del histograma anterior se puede observar que en general las cadenas se caracterizan por tener pocos establecimientos (menos de 10).

# %% [markdown]
# Como conclusión a esta sección, se desprende que las cadenas se caracterizan por tener pocos establecimientos y menos de 50 asientos.

# %% [markdown]
# ### Número de asientos promedio para cada tipo de restaurante

# %%
#cambiando el nombre de las columnas a graficar
type_list = rest_data
type_list.columns = ["id", "object_name", "address", "chain", "establishments", "seats"]

# %%
#graficando el numero de asientos para cada tipo de establecimiento
px.box(rest_data, x="establishments", y="seats", title="Asientos promedio para cada tipo de establecimiento")
# Out:
# <div>                            <div id="877a63a7-82d1-4e37-bb25-fe6243c5957c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("877a63a7-82d1-4e37-bb25-fe6243c5957c")) {                    Plotly.newPlot(                        "877a63a7-82d1-4e37-bb25-fe6243c5957c",                        [{"alignmentgroup":"True","hovertemplate":"establishments=%{x}<br>seats=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Cafe","Restaurant","Fast Food","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Fast Food","Restaurant","Restaurant","Bakery","Restaurant","Fast Food","Bakery","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Bakery","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Fast Food","Restaurant","Fast Food","Restaurant","Bakery","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Fast Food","Cafe","Restaurant","Restaurant","Restaurant","Restaurant","Bar","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Fast Food","Pizza","Restaurant","Fast Food","Restaurant","Restaurant","Restaurant","Fast Food","Fast Food","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Bar","Fast Food","Restaurant","Fast Food","Fast Food","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Fast Food","Restaurant","Restaurant","Bakery","Bakery","Bakery","Restaurant","Restaurant","Restaurant","Cafe","Fast Food","Bar","Restaurant","Restaurant","Restaurant","Fast Food","Fast Food","Restaurant","Bar","Restaurant","Restaurant","Restaurant","Bakery","Restaurant","Pizza","Fast Food","Restaurant","Restaurant","Cafe","Restaurant","Cafe","Bar","Bar","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Fast Food","Restaurant","Restaurant","Pizza","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Bar","Restaurant","Restaurant","Fast Food","Restaurant","Fast Food","Restaurant","Restaurant","Cafe","Cafe","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Fast Food","Fast Food","Restaurant","Restaurant","Restaurant","Cafe","Bar","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Fast Food","Bakery","Restaurant","Restaurant","Fast Food","Restaurant","Restaurant","Pizza","Restaurant","Restaurant","Restaurant","Bakery","Restaurant","Bakery","Restaurant","Restaurant","Restaurant","Restaurant","Fast Food","Fast Food","Restaurant","Restaurant","Restaurant","Fast Food","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Bakery","Bakery","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Fast Food","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Pizza","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Fast Food","Restaurant","Restaurant","Restaurant","Restaurant","Pizza","Pizza","Restaurant","Restaurant","Pizza","Restaurant","Restaurant","Restaurant","Restaurant","Bar","Restaurant","Fast Food","Restaurant","Restaurant","Restaurant","Bar","Restaurant","Cafe","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaurant","Restaura ...

# %% [markdown]
# Los restaurantes y los bares son los establecimientos con mayor cantidad de asientos en promedio.

# %% [markdown]
# ### Mejores calles para restaurantes

# %%
#extrayendo los nombres de las calles en otra columna
rest_data['address_2'] = rest_data['address'].str.extract(pat='([a-zA-Z][\w ]+(?!STE|UNIT|MEZZ|[\w ]+))')
rest_data['address_2'] = rest_data['address_2'].str.strip()
rest_data.head()
# Out:
#       id          object_name                    address  chain  \
# 0  11786  HABITAT COFFEE SHOP     3708 N EAGLE ROCK BLVD  False
# 1  11787             REILLY'S        100 WORLD WAY # 120  False
# 2  11788       STREET CHURROS  6801 HOLLYWOOD BLVD # 253  False
# 3  11789    TRINITI ECHO PARK         1814 W SUNSET BLVD  False
# 4  11790               POLLEN         2100 ECHO PARK AVE  False
#
#   establishments  seats          address_2
# 0           Cafe     26  N EAGLE ROCK BLVD
# 1     Restaurant      9          WORLD WAY
# 2      Fast Food     20     HOLLYWOOD BLVD
# 3     Restaurant     22      W SUNSET BLVD
# 4     Restaurant     20      ECHO PARK AVE

# %%
#arreglando algunos datos
rest_data["address_2"] = rest_data["address_2"].replace("ABBOT KINNEY", "ABBOT KINNEY BLVD")
rest_data["address_2"] = rest_data["address_2"].replace("hollywood BLVD", "HOLLYWOOD BLVD")
rest_data["address_2"] = rest_data["address_2"].replace("Z00 DR", "ZOO DR")

# %%
#agrupando para obtener cantidad de restaurantes por calle
count_streets = rest_data.groupby("address_2").agg({"id":"count"}).sort_values(by="id", ascending=False).reset_index()
count_streets.columns = ["street", "restaurants"]
best_streets = count_streets.head(10)
best_streets
# Out:
#               street  restaurants
# 0      W SUNSET BLVD          327
# 1        W PICO BLVD          313
# 2      WILSHIRE BLVD          245
# 3  SANTA MONICA BLVD          211
# 4      S WESTERN AVE          208
# 5     HOLLYWOOD BLVD          204
# 6           W 3RD ST          183
# 7      S FIGUEROA ST          178
# 8      S VERMONT AVE          177
# 9     W OLYMPIC BLVD          163

# %%
#graficando las mejores calles
fig = px.bar(best_streets, x="street", y="restaurants", title="10 calles con más restaurantes")
fig.update_xaxes(tickangle=45)
fig.show()
# Out:
# <div>                            <div id="4c351cf4-75b3-4f71-ad1d-eb6c0f57fc40" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c351cf4-75b3-4f71-ad1d-eb6c0f57fc40")) {                    Plotly.newPlot(                        "4c351cf4-75b3-4f71-ad1d-eb6c0f57fc40",                        [{"alignmentgroup":"True","hovertemplate":"street=%{x}<br>restaurants=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["W SUNSET BLVD","W PICO BLVD","WILSHIRE BLVD","SANTA MONICA BLVD","S WESTERN AVE","HOLLYWOOD BLVD","W 3RD ST","S FIGUEROA ST","S VERMONT AVE","W OLYMPIC BLVD"],"xaxis":"x","y":[327,313,245,211,208,204,183,178,177,163],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"ba ...

# %% [markdown]
# ### Peores calles para restaurantes

# %%
#conteo de las calles con solo 1 restaurante
count_streets[count_streets["restaurants"]==1]["street"].count()
# Out:
# 1211

# %% [markdown]
# ### Distribución del número de asientos en las mejores calles

# %%
#creando una lista de las mejores calles
best_streets_list = list(best_streets["street"])
best_streets_list
# Out:
# ['W SUNSET BLVD',
#  'W PICO BLVD',
#  'WILSHIRE BLVD',
#  'SANTA MONICA BLVD',
#  'S WESTERN AVE',
#  'HOLLYWOOD BLVD',
#  'W 3RD ST',
#  'S FIGUEROA ST',
#  'S VERMONT AVE',
#  'W OLYMPIC BLVD']

# %%
#obteniendo el dataset solo de las mejores calles
best_data = rest_data.query('address_2 in @best_streets_list')
best_data
# Out:
#          id                object_name                         address  chain  \
# 2     11788             STREET CHURROS       6801 HOLLYWOOD BLVD # 253  False
# 3     11789          TRINITI ECHO PARK              1814 W SUNSET BLVD  False
# 10    11796              EL POLLO LOCO              5319 W SUNSET BLVD   True
# 14    11800          CUSCATLECA BAKERY           2501 W SUNSET BLVD #A   True
# 16    11802                 HMS BOUNTY              3357 WILSHIRE BLVD  False
# ...     ...                        ...                             ...    ...
# 9628  21414                  KIFF KAFE               12217 W PICO BLVD  False
# 9635  21421  THE TEA & COFFEE EXCHANGE       6801 HOLLYWOOD BLVD # 120  False
# 9639  21425                 MCDONALD'S              1800 S WESTERN AVE   True
# 9645  21431                 SAINT MARC  10250 SANTA MONICA BLVD # 1025  False
# 9648  21434                JUICY WINGZ             6741 HOLLYWOOD BLVD   True
#
#      establishments  seats          address_2
# 2         Fast Food     20     HOLLYWOOD BLVD
# 3        Restaurant     22      W SUNSET BLVD
# 10       Restaurant     38      W SUNSET BLVD
# 14           Bakery     26      W SUNSET BLVD
# 16       Restaurant    147      WILSHIRE BLVD
# ...             ...    ...                ...
# 9628     Restaurant     29        W PICO BLVD
# 9635           Cafe      4     HOLLYWOOD BLVD
# 9639      Fast Food    135      S WESTERN AVE
# 9645     Restaurant    225  SANTA MONICA BLVD
# 9648      Fast Food     15     HOLLYWOOD BLVD
#
# [2209 rows x 7 columns]

# %%
#graficando el histograma
fig = px.histogram(best_data, x="seats", nbins = 20, title="Distribución del número de asientos en las mejores calles")
fig.show()
# Out:
# <div>                            <div id="9483b18f-443a-46c8-8f8e-25e37053e9dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9483b18f-443a-46c8-8f8e-25e37053e9dd")) {                    Plotly.newPlot(                        "9483b18f-443a-46c8-8f8e-25e37053e9dd",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"seats=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":20,"offsetgroup":"","orientation":"v","showlegend":false,"x":[20,22,38,26,147,39,31,118,182,35,15,49,158,18,33,13,22,35,16,45,16,28,3,131,40,6,7,23,107,134,107,8,62,45,22,4,8,12,20,8,23,225,21,19,100,221,34,10,49,23,71,122,37,5,15,19,6,5,14,77,27,12,48,44,85,3,47,167,3,9,217,185,111,47,12,135,149,27,43,143,17,11,46,14,45,27,85,89,164,84,131,47,18,8,20,23,34,20,14,31,86,69,190,92,33,139,25,40,129,37,37,34,46,26,28,18,108,23,25,7,108,3,15,24,2,1,70,26,5,64,33,9,10,1,18,127,80,49,74,29,24,184,26,12,205,15,3,12,9,115,99,47,17,49,9,48,19,6,48,31,74,9,87,171,31,106,35,203,40,26,12,46,41,22,22,7,87,90,21,1,36,26,110,24,8,20,194,48,2,28,184,86,19,24,8,3,24,16,25,14,43,29,115,12,21,2,6,24,1,27,37,6,17,28,33,16,25,38,46,12,18,12,132,212,38,18,226,34,39,15,10,140,18,6,6,33,145,112,10,92,7,126,193,19,118,20,19,203,45,3,18,67,42,109,25,14,32,198,3,1,18,19,192,115,25,46,34,2,111,26,42,111,64,49,44,186,1,204,4,15,15,159,28,10,41,107,32,36,182,43,18,31,20,68,189,2,47,9,66,11,34,11,40,38,18,181,82,100,94,172,5,46,45,181,84,2,197,27,34,106,141,28,25,81,22,10,93,80,124,19,5,20,27,48,38,109,10,9,9,22,5,45,1,112,45,11,136,40,1,120,145,16,220,25,26,131,220,112,110,21,22,3,124,8,43,15,42,12,39,40,40,17,20,85,27,21,22,63,17,161,110,42,77,77,44,39,83,21,173,11,8,8,21,67,105,3,124,106,19,128,1,76,28,1,43,49,45,68,43,70,10,102,6,3,34,11,117,107,42,7,134,87,45,22,7,110,47,29,168,18,31,29,223,48,24,1,36,227,37,113,29,32,21,6,13,1,38,96,225,17,43,28,22,47,127,109,8,5,16,13,187,1,2,41,178,11,166,83,40,17,28,37,117,107,49,35,13,22,18,2,114,102,136,92,41,8,34,211,29,69,20,16,125,102,75,126,12,2,47,4,89,127,8,164,4,33,37,16,6,26,23,32,4,35,20,125,5,170,110,74,44,47,29,10,94,29,35,100,21,213,36,46,144,13,87,28,41,28,8,85,107,5,119,24,1,80,19,26,33,45,44,36,136,47,44,48,49,14,148,35,118,22,22,28,39,20,44,3,31,198,161,149,20,28,43,9,105,19,25,17,155,80,204,41,126,27,27,12,13,28,94,16,132,22,2,102,35,32,12,74,33,48,31,6,42,32,149,144,8,34,7,8,96,22,96,77,10,31,25,122,20,8,46,47,63,24,26,18,25,65,20,116,10,18,12,37,20,34,8,26,32,123,19,122,73,222,28,12,22,33,46,12,2,37,44,123,48,172,16,47,10,20,122,47,24,12,10,7,136,4,37,10,49,5,34,5,24,7,40,209,40,37,47,41,8,21,20,9,24,62,48,26,29,2,168,10,33,12,28,25,5,21,2,108,11,41,12,84,46,49,29,105,17,45,3,14,184,49,29,19,17,36,99,17,3,44,16,47,130,148,132,16,48,37,91,145,15,35,44,11,42,20,145,69,19,145,13,33,26,39,7,36,67,29,35,16,95,13,39,32,148,14,12,11,65,4,29,18,40,114,103,78,35,38,194,11,49,64,11,43,18,4,2,23,10,80,9,9,32,24,133,70,33,2,139,74,33,107,71,46,18,40,226,47,48,11,44,24,6,37,48,2,130,76,147,24,21,28,199,19,46,101,115,136,40,45,36,165,157,103,98,19,19,42,36,41,18,41,17,3,32,39,44,106,130,75,13,16,22,25,9,10,22,42,66,138,67,39,4,34,6,48,17,23,6,43,39,104,39,95,31,26,5,6,3,5,46,46,42,1,6,92,49,4,15,131,8,10,5,34,43,39,161,116,165,43,40,13,42,19,17,25,27,39,14,2,124,2,31,14,48,39,19,66,44,42,3,157,26,35,9,31,5,8,1,3,29,169,120,9,3,47,46,19,11,132,42,14,72,218,48,25,134,167,45,12,36,16,13,20,133,28,28,8,141,209,17,28,12,23,33,26,133,2,24,34,20,11,87,28,31,38,73,37,23,179,135,3,226,28,8,9,105,22,37,13,13,143,68,100,34,20,111,6,3,43,7,205,38,17,99,19,17,14,35,5,14,27,8,8,21,33,24,21,167,46,118,18,44,37,18,31,13,128,1,41,4,1,4,49,44,3,143,46,5,126,11,6,43,116,64,15,40,35,14,88,31,16,83,21,6,32,24,48,2,44,48,158,11 ...

# %% [markdown]
# La tendencia de la distribución del número de asiento en las mejores calles no varía mucho a las demás. Existen muchos más establecimientos con pocos asientos.

# %% [markdown]
# ## PRESENTACIÓN

# %% [markdown]
# Presentation: <https://drive.google.com/file/d/13RcWkGpM8sMdG-xJN1NuTQymm7Opv9Pz/view?usp=sharing>

# %% [markdown]
# ## CONCLUSIÓN Y RECOMENDACIONES

# %% [markdown]
# El estudio de la base de datos presentada determinó que la competencia de cafeterías es bastante pequeña en comparación con otros tipos de establecimientos como los restaurantes, por lo que llamará bastante la atención la entrada al mercado de una cafetería regentada por robots.
#
# Como recomendación, la cafetería debe formar parte de una cadena, y los locales deben estar ubicados en las calles más populares, ya que es ahí donde concurrirá mucha gente. También sería importante mantener una baja cantidad de asientos, ya que así se potencia la rápida rotación de los clientes.
